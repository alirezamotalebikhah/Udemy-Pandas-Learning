# %%
import pandas as pd
df = pd.DataFrame({
    'A':[1,2,None,4],
    'B':[None,3,4,None],
    'C':[5,None,None,6]
})

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
 df.isna()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False   True
# 3  False   True  False

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.isna()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False   True
# 3  False   True  False

# %%
df[df.isna()]
# Out:
#     A   B   C
# 0 NaN NaN NaN
# 1 NaN NaN NaN
# 2 NaN NaN NaN
# 3 NaN NaN NaN

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False   True
# 2   True  False   True
# 3  False   True  False

# %%
df.notnull()
# Out:
#        A      B      C
# 0   True  False   True
# 1   True   True  False
# 2  False   True  False
# 3   True  False   True

# %%
df.notna()
# Out:
#        A      B      C
# 0   True  False   True
# 1   True   True  False
# 2  False   True  False
# 3   True  False   True

# %%
df.notnull()
# Out:
#        A      B      C
# 0   True  False   True
# 1   True   True  False
# 2  False   True  False
# 3   True  False   True

# %%
df.fillna(0)
# Out:
#      A    B    C
# 0  1.0  0.0  5.0
# 1  2.0  3.0  0.0
# 2  0.0  4.0  0.0
# 3  4.0  0.0  6.0

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.fillna("boared training")
# Out:
#                  A                B                C
# 0              1.0  boared training              5.0
# 1              2.0              3.0  boared training
# 2  boared training              4.0  boared training
# 3              4.0  boared training              6.0

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.ffill()
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  5.0
# 2  2.0  4.0  5.0
# 3  4.0  4.0  6.0

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.bfill()
# Out:
#      A    B    C
# 0  1.0  3.0  5.0
# 1  2.0  3.0  6.0
# 2  4.0  4.0  6.0
# 3  4.0  NaN  6.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.dropna(how='all')
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
df.dropna(how="any")
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  6.0

# %%
import pandas as pd
df = pd.DataFrame({
    'A':[1,2,None,4],
    'B':[None,3,4,None],
    'C':[5,None,None,None]
})

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  NaN

# %%
df.dropna(how='all')
# Out:
#      A    B    C
# 0  1.0  NaN  5.0
# 1  2.0  3.0  NaN
# 2  NaN  4.0  NaN
# 3  4.0  NaN  NaN

# %%
import pandas as pd
df = pd.DataFrame({
    'A':[None,None,None,None],
    'B':[None,3,4,None],
    'C':[5,None,None,None]
})

# %%
df
# Out:
#       A    B    C
# 0  None  NaN  5.0
# 1  None  3.0  NaN
# 2  None  4.0  NaN
# 3  None  NaN  NaN

# %%
df.dropna(how='all',axis=1)
# Out:
#      B    C
# 0  NaN  5.0
# 1  3.0  NaN
# 2  4.0  NaN
# 3  NaN  NaN

# %%
df.drop(columns=['C'])
# Out:
#       A    B
# 0  None  NaN
# 1  None  3.0
# 2  None  4.0
# 3  None  NaN

# %%
df
# Out:
#       A    B    C
# 0  None  NaN  5.0
# 1  None  3.0  NaN
# 2  None  4.0  NaN
# 3  None  NaN  NaN

# %%
df.drop(index=2)
# Out:
#       A    B    C
# 0  None  NaN  5.0
# 1  None  3.0  NaN
# 3  None  NaN  NaN

# %%
df =pd.DataFrame({
    'X':[1,1,2,3,4,4],
    'Y':[5,5,7,7,8,9]
})

# %%
df
# Out:
#    X  Y
# 0  1  5
# 1  1  5
# 2  2  7
# 3  3  7
# 4  4  8
# 5  4  9

# %%
df.drop_duplicates()
# Out:
#    X  Y
# 0  1  5
# 2  2  7
# 3  3  7
# 4  4  8
# 5  4  9

# %%
df.drop_duplicates(subset='X')
# Out:
#    X  Y
# 0  1  5
# 2  2  7
# 3  3  7
# 4  4  8
