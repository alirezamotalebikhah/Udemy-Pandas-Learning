# %%
import pandas as pd
from sqlalchemy import create_engine

# connection string
engine = create_engine(
    "postgresql+psycopg2://udemy:udemy123@localhost:5434/udemy_master_of_pandas"
)

# read table
employees = pd.read_sql("SELECT * FROM master.employees;", engine)

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry    None  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                  None
# ...

# %%
employees[['First Name' , 'Salary' , 'Team']]
# Out:
#     First Name  Salary                  Team
# 0      Douglas   97308             Marketing
# 1       Thomas   61933                  None
# 2        Maria  130590               Finance
# 3        Jerry  138705               Finance
# 4        Larry  101004       Client Services
# ..         ...     ...                   ...
# 995      Henry  132483          Distribution
# 996    Phillip   42392               Finance
# 997    Russell   96914               Product
# 998      Larry   60500  Business Development
# 999     Albert  129949                 Sales
#
# [1000 rows x 3 columns]

# %%
employees.get(['First Name' , 'Salary' , 'Team'])
# Out:
#     First Name  Salary                  Team
# 0      Douglas   97308             Marketing
# 1       Thomas   61933                  None
# 2        Maria  130590               Finance
# 3        Jerry  138705               Finance
# 4        Larry  101004       Client Services
# ..         ...     ...                   ...
# 995      Henry  132483          Distribution
# 996    Phillip   42392               Finance
# 997    Russell   96914               Product
# 998      Larry   60500  Business Development
# 999     Albert  129949                 Sales
#
# [1000 rows x 3 columns]

# %%
employees.loc[0,'First Name']
# Out:
# 'Douglas'

# %%
employees.loc[[2,32,1],['First Name' , 'Salary']]
# Out:
#    First Name  Salary
# 2       Maria  130590
# 32       None  122340
# 1      Thomas   61933

# %%
employees.loc[:10 , 'Salary':]
# Out:
#     Salary  Bonus % Senior Management                  Team
# 0    97308    6.945              True             Marketing
# 1    61933    4.170              True                  None
# 2   130590   11.858             False               Finance
# 3   138705    9.340              True               Finance
# 4   101004    1.389              True       Client Services
# 5   115163   10.125             False                 Legal
# 6    65476   10.012              True               Product
# 7    45906   11.598              None               Finance
# 8    95570   18.523              True           Engineering
# 9   139852    7.524              True  Business Development
# 10   63241   15.132              True                  None

# %%
employees.set_index('First Name' , inplace = True)

# %%
employees.loc[['Thomas' , 'Maria'],['Gernder' , 'Salary']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 employees.loc[['Thomas' , 'Maria'],['Gernder' , 'Salary']]
#
# File ~/workspace/udemy/Master of Pandas/Udemy-Pandas-Learning/env/lib/python3.12/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~/workspace/udemy/Master of Pandas/Udemy-Pandas-Learning/env/lib/python3.12/site-packages/pandas/core/indexing.py:1376, in _LocIndexer._getitem_tuple(self, tup)
#    1374 # ugly hack for GH #836
#    1375 if self._multi_take_opportunity(tup):
# -> 1376     return self._multi_take(tup)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 employees.loc[['Thomas' , 'Maria'],['Gernder' , 'Salary']]
#
# File ~/workspace/udemy/Master of Pandas/Udemy-Pandas-Learning/env/lib/python3.12/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~/workspace/udemy/Master of Pandas/Udemy-Pandas-Learning/env/lib/python3.12/site-packages/pandas/core/indexing.py:1376, in _LocIndexer._getitem_tuple(self, tup)
#    1374 # ugly hack for GH #836
#    1375 if self._multi_take_opportunity(tup):
# -> 1376     return self._multi_take(tup)
# ...
