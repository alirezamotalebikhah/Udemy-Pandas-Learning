# %%
import pandas as pd
from sqlalchemy import create_engine
# connection string
engine = create_engine(
    "postgresql+psycopg2://udemy:udemy123@localhost:5434/udemy_master_of_pandas"
)

# read table
employees = pd.read_sql("SELECT * FROM master.employees;", engine)

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry    None  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                  None
# ...

# %%
employees.sort_index()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry    None  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                  None
# ...

# %%
employees.sort_index(ascending=False)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 995      Henry    None  11/23/2014         6:09 AM  132483   16.655
# ..         ...     ...         ...             ...     ...      ...
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
#
#     Senior Management                  Team
# 999              True                 Sales
# 998             False  Business Development
# ...

# %%
employees.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#         'Bonus %', 'Senior Management', 'Team'],
#        dtype='object')]

# %% [markdown]
# empolyees.axes[0]

# %%
employees.axes[0]
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
employees.axes[1]
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
employees.sort_index(axis=1)
# Out:
#      Bonus % First Name  Gender Last Login Time  Salary Senior Management  \
# 0      6.945    Douglas    Male        12:42 PM   97308              True
# 1      4.170     Thomas    Male         6:53 AM   61933              True
# 2     11.858      Maria  Female        11:17 AM  130590             False
# 3      9.340      Jerry    Male         1:00 PM  138705              True
# 4      1.389      Larry    Male         4:47 PM  101004              True
# ..       ...        ...     ...             ...     ...               ...
# 995   16.655      Henry    None         6:09 AM  132483             False
# 996   19.675    Phillip    Male         6:30 AM   42392             False
# 997    1.421    Russell    Male        12:39 PM   96914             False
# 998   11.985      Larry    Male         4:45 PM   60500             False
# 999   10.169     Albert    Male         6:24 PM  129949              True
#
#      Start Date                  Team
# 0      8/6/1993             Marketing
# ...

# %%
col_index = employees.axes[1]

# %%
sorted(col_index)
# Out:
# ['Bonus %',
#  'First Name',
#  'Gender',
#  'Last Login Time',
#  'Salary',
#  'Senior Management',
#  'Start Date',
#  'Team']

# %%
employees.sort_index(axis=1 , ascending=False)
# Out:
#                      Team  Start Date Senior Management  Salary  \
# 0               Marketing    8/6/1993              True   97308
# 1                    None   3/31/1996              True   61933
# 2                 Finance   4/23/1993             False  130590
# 3                 Finance    3/4/2005              True  138705
# 4         Client Services   1/24/1998              True  101004
# ..                    ...         ...               ...     ...
# 995          Distribution  11/23/2014             False  132483
# 996               Finance   1/31/1984             False   42392
# 997               Product   5/20/2013             False   96914
# 998  Business Development   4/20/2013             False   60500
# 999                 Sales   5/15/2012              True  129949
#
#     Last Login Time  Gender First Name  Bonus %
# 0          12:42 PM    Male    Douglas    6.945
# 1           6:53 AM    Male     Thomas    4.170
# 2          11:17 AM  Female      Maria   11.858
# ...

# %%
 employees.sort_index(axis = 1,key=lambda c : c.str.len())
# Out:
#                      Team  Gender  Salary  Bonus % First Name  Start Date  \
# 0               Marketing    Male   97308    6.945    Douglas    8/6/1993
# 1                    None    Male   61933    4.170     Thomas   3/31/1996
# 2                 Finance  Female  130590   11.858      Maria   4/23/1993
# 3                 Finance    Male  138705    9.340      Jerry    3/4/2005
# 4         Client Services    Male  101004    1.389      Larry   1/24/1998
# ..                    ...     ...     ...      ...        ...         ...
# 995          Distribution    None  132483   16.655      Henry  11/23/2014
# 996               Finance    Male   42392   19.675    Phillip   1/31/1984
# 997               Product    Male   96914    1.421    Russell   5/20/2013
# 998  Business Development    Male   60500   11.985      Larry   4/20/2013
# 999                 Sales    Male  129949   10.169     Albert   5/15/2012
#
#     Last Login Time Senior Management
# 0          12:42 PM              True
# ...

# %%
 employees.sort_index(axis = 1,key=lambda c : c.str.len(), ascending=False)
# Out:
#     Senior Management Last Login Time  Start Date First Name  Bonus %  Gender  \
# 0                True        12:42 PM    8/6/1993    Douglas    6.945    Male
# 1                True         6:53 AM   3/31/1996     Thomas    4.170    Male
# 2               False        11:17 AM   4/23/1993      Maria   11.858  Female
# 3                True         1:00 PM    3/4/2005      Jerry    9.340    Male
# 4                True         4:47 PM   1/24/1998      Larry    1.389    Male
# ..                ...             ...         ...        ...      ...     ...
# 995             False         6:09 AM  11/23/2014      Henry   16.655    None
# 996             False         6:30 AM   1/31/1984    Phillip   19.675    Male
# 997             False        12:39 PM   5/20/2013    Russell    1.421    Male
# 998             False         4:45 PM   4/20/2013      Larry   11.985    Male
# 999              True         6:24 PM   5/15/2012     Albert   10.169    Male
#
# ...

# %%
 employees.sort_index(axis = 0,key=lambda r : r % 10 == 1 , ascending=False)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
# 341     Carlos    Male   9/19/2007         1:01 AM   77327   11.580
# 681      Frank    Male  11/23/2002         6:10 PM   75147   17.398
# 431    Charles    Male  12/16/1999         8:28 PM  104014    7.077
# 611  Elizabeth    None   2/16/1981         3:58 AM   52730   12.525
# ..         ...     ...         ...             ...     ...      ...
# 354  Elizabeth  Female  11/10/2005         4:56 AM  106406    1.782
# 355     Andrea  Female   9/14/2003        10:30 PM  115913   12.121
# 356       Judy  Female    2/1/1990         3:32 PM   38092    5.668
# 357    Russell    Male   8/13/2014         3:51 PM  121160    7.843
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 291              True  Client Services
# 341              True          Finance
# ...
