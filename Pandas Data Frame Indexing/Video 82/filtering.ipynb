# %%
import pandas as pd
from sqlalchemy import create_engine
# connection string
engine = create_engine(
    "postgresql+psycopg2://udemy:udemy123@localhost:5434/udemy_master_of_pandas"
)

# read table
employees = pd.read_sql("SELECT * FROM archive.employee_data;", engine)

# %%
employees
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 1      3428     Paula       Small  11-Feb-23        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 3      3430   Michael     Riordan  21-Jun-21        NaN
# 4      3431   Jasmine       Onque  29-Jun-19        NaN
# ...     ...       ...         ...        ...        ...
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
# 2997   3424   Annabel     Wilkins  09-Dec-20  04-Aug-22
# 2998   3425    Kendra       Braun  28-May-19  23-Oct-21
# 2999   3426     Chace        Kerr  27-Apr-22        NaN
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# 2          Area Sales Manager      Crystal Walker
# 3          Area Sales Manager      Rebekah Wright
# ...

# %%
 employees.columns
# Out:
# Index(['EmpID', 'FirstName', 'LastName', 'StartDate', 'ExitDate', 'Title',
#        'Supervisor', 'ADEmail', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'TerminationType', 'TerminationDescription', 'DepartmentType',
#        'Division', 'DOB', 'State', 'JobFunctionDescription', 'GenderCode',
#        'LocationCode', 'RaceDesc', 'MaritalDesc', 'Performance Score',
#        'Current Employee Rating'],
#       dtype='str')

# %%
 employees['Title']
# Out:
# 0       Production Technician I
# 1       Production Technician I
# 2            Area Sales Manager
# 3            Area Sales Manager
# 4            Area Sales Manager
#                  ...
# 2995    Production Technician I
# 2996    Production Technician I
# 2997    Production Technician I
# 2998    Production Technician I
# 2999    Production Technician I
# Name: Title, Length: 3000, dtype: str

# %%
employees['Title'].unique()
# Out:
# <StringArray>
# [     'Production Technician I',           'Area Sales Manager',
#      'Production Technician II',                   'IT Support',
#              'Network Engineer',         'Sr. Network Engineer',
#      'Principal Data Architect',         'Enterprise Architect',
#                       'Sr. DBA',       'Database Administrator',
#                  'Data Analyst',                'Data Analyst ',
#                'Data Architect',                          'CIO',
#                   'BI Director',               'Sr. Accountant',
#  'Software Engineering Manager',            'Software Engineer',
#       'Shared Services Manager',          'Senior BI Developer',
#            'Production Manager',              'President & CEO',
#      'Administrative Assistant',                 'Accountant I',
#                 'Sales Manager',                 'BI Developer',
#          'IT Manager - Support',           'IT Manager - Infra',
# ...

# %%
employees['Title'].unique()=='Production Technician I'
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
 employees['Title']=='Production Technician I'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998     True
# 2999     True
# Name: Title, Length: 3000, dtype: bool

# %%
employees[employees['Title']=='Production Technician I']
# Out:
#       EmpID FirstName     LastName  StartDate   ExitDate  \
# 0      3427     Uriah      Bridges  20-Sep-19        NaN
# 1      3428     Paula        Small  11-Feb-23        NaN
# 131    3558   Mildred       Gentry  30-Dec-18        NaN
# 132    3559  Wilson K     Adinolfi  06-Nov-19  06-Sep-20
# 133    3560    Joanne  Handschiegl  01-Jun-22        NaN
# ...     ...       ...          ...        ...        ...
# 2995   3422    Jakobe     Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson   Strickland  28-Dec-20        NaN
# 2997   3424   Annabel      Wilkins  09-Dec-20  04-Aug-22
# 2998   3425    Kendra        Braun  28-May-19  23-Oct-21
# 2999   3426     Chace         Kerr  27-Apr-22        NaN
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# 131   Production Technician I          Erin Moore
# 132   Production Technician I    Andrea Gutierrez
# ...

# %%
employees[employees['Title']=='Data Architect']
# Out:
#       EmpID  FirstName  LastName  StartDate   ExitDate           Title  \
# 532    3959    Braylen   Mendoza  11-Nov-22  14-Jul-23  Data Architect
# 547    3974     Zander    Franco  25-Dec-18  10-Jul-19  Data Architect
# 560    3987      Aydan  Benjamin  25-Feb-22  19-Jul-22  Data Architect
# 573    4000  Angelique      Mann  26-Oct-19  08-Jun-21  Data Architect
# 1200   1626      Katie     Roper  17-Sep-20  08-Jun-21  Data Architect
#
#            Supervisor                        ADEmail BusinessUnit  \
# 532   Douglas Chapman  braylen.mendoza@bilearner.com          PYZ
# 547     Ronnie Garcia    zander.franco@bilearner.com          BPC
# 560    Lindsay Nelson   aydan.benjamin@bilearner.com          PYZ
# 573     Eugene Morgan   angelique.mann@bilearner.com          PYZ
# 1200    William Green      katie.roper@bilearner.com           PL
#
#             EmployeeStatus  ...          Division         DOB State  \
# 532   Terminated for Cause  ...     General - Con  20-08-1988    TX
# ...

# %%
employees['EmployeeStatus'].unique()
# Out:
# <StringArray>
# [                'Active',           'Future Start', 'Voluntarily Terminated',
#        'Leave of Absence',   'Terminated for Cause']
# Length: 5, dtype: str

# %%
employees['EmployeeStatus']=='Leave of Absence'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: EmployeeStatus, Length: 3000, dtype: bool

# %%
employees[employees['EmployeeStatus']=='Leave of Absence']
# Out:
#       EmpID FirstName   LastName  StartDate   ExitDate  \
# 389    3814     Jyoti     Lajiri  07-Jan-19  05-Sep-20
# 407    3832    Sloane  Rasmussen  02-Aug-21  29-Sep-22
# 415    3842      Kyla     Durham  20-Aug-20  11-Aug-21
# 416    3843   Cassidy     Maddox  16-Jul-23  30-Jul-23
# 424    3851     Vance    Marquez  18-Jan-19  30-Mar-20
# ...     ...       ...        ...        ...        ...
# 2963   3390    Lizeth  Middleton  21-Oct-22  05-Jan-23
# 2974   3401    Taniya       Kane  10-Nov-21  04-Jun-23
# 2977   3404    Willie       Howe  25-Apr-19  11-Nov-22
# 2978   3405    Selina  Jefferson  13-Jan-20  21-Oct-22
# 2995   3422    Jakobe   Erickson  22-Jun-22  07-Aug-22
#
#                          Title         Supervisor  \
# 389       Sr. Network Engineer     Karen Crawford
# 407                    Sr. DBA   Melinda Mcintyre
# 415       Enterprise Architect  Clayton Robertson
# 416                    Sr. DBA     Melissa Pineda
# ...

# %%
 employees['EmployeeType'].unique()
# Out:
# <StringArray>
# ['Contract', 'Full-Time', 'Part-Time']
# Length: 3, dtype: str

# %%
employees['EmployeeType']=='Full-Time'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999     True
# Name: EmployeeType, Length: 3000, dtype: bool

# %%
employees[employees['EmployeeType']=='Full-Time']
# Out:
#       EmpID    FirstName  LastName  StartDate   ExitDate  \
# 2      3429       Edward      Buck  10-Dec-18        NaN
# 6      3433        Latia     Costa  06-Apr-22  03-Jul-23
# 11     3438       Dheepa    Nguyen  10-Aug-18  04-Nov-19
# 12     3439  Bartholemew  Khemmich  25-May-22  27-Nov-22
# 15     3442       Kaylah      Moon  09-Jul-19  16-Jun-22
# ...     ...          ...       ...        ...        ...
# 2973   3400      Lorenzo     Short  21-Sep-21        NaN
# 2984   3411       Brenda     Boone  06-Oct-22        NaN
# 2988   3415       Julien  Cisneros  09-Sep-22  16-Mar-23
# 2989   3416         Aron    Waters  02-Oct-20        NaN
# 2999   3426        Chace      Kerr  27-Apr-22        NaN
#
#                          Title       Supervisor  \
# 2           Area Sales Manager   Crystal Walker
# 6           Area Sales Manager      Jacob Braun
# 11          Area Sales Manager     Brian Miller
# 12          Area Sales Manager    Charles Parks
# ...

# %%
employees[employees['EmployeeType']=='Contract']
# Out:
#       EmpID FirstName LastName  StartDate   ExitDate                    Title  \
# 0      3427     Uriah  Bridges  20-Sep-19        NaN  Production Technician I
# 1      3428     Paula    Small  11-Feb-23        NaN  Production Technician I
# 3      3430   Michael  Riordan  21-Jun-21        NaN       Area Sales Manager
# 4      3431   Jasmine    Onque  29-Jun-19        NaN       Area Sales Manager
# 5      3432     Maruk   Fraval  17-Jan-20        NaN       Area Sales Manager
# ...     ...       ...      ...        ...        ...                      ...
# 2987   3414    Hunter    Silva  03-Jun-22        NaN  Production Technician I
# 2992   3419   Stanley    Reyes  14-Oct-19        NaN  Production Technician I
# 2993   3420      Levi   Hayden  10-Oct-20  05-Aug-22  Production Technician I
# 2997   3424   Annabel  Wilkins  09-Dec-20  04-Aug-22  Production Technician I
# 2998   3425    Kendra    Braun  28-May-19  23-Oct-21  Production Technician I
#
# ...

# %%
employees[employees['EmployeeType']=='Part-Time']
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 9      3436    Joseph     Martins  21-Jan-22  29-Jun-23
# 14     3441    Prater      Jeremy  28-Apr-19        NaN
# 19     3446    Hector      Dalton  24-Aug-21        NaN
# 20     3447   Mariela     Schultz  26-May-20  18-Jun-23
# 25     3452    Jaydon   Blackburn  08-Nov-22        NaN
# ...     ...       ...         ...        ...        ...
# 2990   3417   Brayden       Singh  07-Feb-22        NaN
# 2991   3418     Karma      Palmer  14-Oct-22        NaN
# 2994   3421   Brenden       Leach  09-May-22  08-Sep-22
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
#
#                         Title         Supervisor  \
# 9          Area Sales Manager     George Jenkins
# 14         Area Sales Manager        Tyler Lewis
# 19         Area Sales Manager      Sydney French
# 20         Area Sales Manager  Michelle Evans MD
# ...

# %%
 employees['PayZone'].unique()
# Out:
# <StringArray>
# ['Zone C', 'Zone A', 'Zone B']
# Length: 3, dtype: str

# %%
 employees['PayZone'] == 'Zone C'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: PayZone, Length: 3000, dtype: bool

# %%
employees[ employees['PayZone'] == 'Zone C']
# Out:
#       EmpID FirstName  LastName  StartDate   ExitDate  \
# 0      3427     Uriah   Bridges  20-Sep-19        NaN
# 7      3434  Sharlene     Terry  06-Nov-20  29-Jan-23
# 11     3438    Dheepa    Nguyen  10-Aug-18  04-Nov-19
# 16     3443   Kristen      Tate  05-Apr-21  12-May-23
# 18     3445      Reid      Park  16-Jan-21        NaN
# ...     ...       ...       ...        ...        ...
# 2980   3407    Kamila   Sanders  15-Apr-21  11-May-23
# 2983   3410      Laci     Klein  18-Dec-18        NaN
# 2987   3414    Hunter     Silva  03-Jun-22        NaN
# 2992   3419   Stanley     Reyes  14-Oct-19        NaN
# 2995   3422    Jakobe  Erickson  22-Jun-22  07-Aug-22
#
#                          Title            Supervisor  \
# 0      Production Technician I          Peter Oneill
# 7           Area Sales Manager         Tracy Marquez
# 11          Area Sales Manager          Brian Miller
# 16          Area Sales Manager          Lauren Jones
# ...

# %%
employees['Current Employee Rating'].unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
employees['Current Employee Rating'] == 4
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: Current Employee Rating, Length: 3000, dtype: bool

# %%
employees[employees['Current Employee Rating'] == 4]
# Out:
#       EmpID FirstName  LastName  StartDate   ExitDate  \
# 0      3427     Uriah   Bridges  20-Sep-19        NaN
# 2      3429    Edward      Buck  10-Dec-18        NaN
# 6      3433     Latia     Costa  06-Apr-22  03-Jul-23
# 14     3441    Prater    Jeremy  28-Apr-19        NaN
# 18     3445      Reid      Park  16-Jan-21        NaN
# ...     ...       ...       ...        ...        ...
# 2950   3377      Cruz    Ashley  24-Feb-20  13-May-23
# 2952   3379   Marquis    Joseph  09-Apr-23  14-Jun-23
# 2969   3396   Stephen  Mcmillan  05-Apr-21  29-Nov-21
# 2982   3409   Brenton    Zavala  08-Oct-22  04-Feb-23
# 2991   3418     Karma    Palmer  14-Oct-22        NaN
#
#                          Title         Supervisor  \
# 0      Production Technician I       Peter Oneill
# 2           Area Sales Manager     Crystal Walker
# 6           Area Sales Manager        Jacob Braun
# 14          Area Sales Manager        Tyler Lewis
# 18          Area Sales Manager  Michelle Mitchell
# ...

# %%
employees[employees['Current Employee Rating'] > 3]
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 6      3433     Latia       Costa  06-Apr-22  03-Jul-23
# 9      3436    Joseph     Martins  21-Jan-22  29-Jun-23
# 10     3437    Myriam      Givens  04-Aug-23        NaN
# ...     ...       ...         ...        ...        ...
# 2979   3406  Serenity  Montgomery  25-Mar-20  26-Apr-23
# 2980   3407    Kamila     Sanders  15-Apr-21  11-May-23
# 2982   3409   Brenton      Zavala  08-Oct-22  04-Feb-23
# 2986   3413   Jovanny    Matthews  25-Nov-19        NaN
# 2991   3418     Karma      Palmer  14-Oct-22        NaN
#
#                          Title      Supervisor  \
# 0      Production Technician I    Peter Oneill
# 2           Area Sales Manager  Crystal Walker
# 6           Area Sales Manager     Jacob Braun
# 9           Area Sales Manager  George Jenkins
# 10          Area Sales Manager      Troy White
# ...

# %%
employees[employees['Current Employee Rating'] >= 3]
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 1      3428     Paula       Small  11-Feb-23        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 4      3431   Jasmine       Onque  29-Jun-19        NaN
# 5      3432     Maruk      Fraval  17-Jan-20        NaN
# ...     ...       ...         ...        ...        ...
# 2987   3414    Hunter       Silva  03-Jun-22        NaN
# 2988   3415    Julien    Cisneros  09-Sep-22  16-Mar-23
# 2991   3418     Karma      Palmer  14-Oct-22        NaN
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
#
#                         Title       Supervisor  \
# 0     Production Technician I     Peter Oneill
# 1     Production Technician I  Renee Mccormick
# 2          Area Sales Manager   Crystal Walker
# 4          Area Sales Manager        Jason Kim
# 5          Area Sales Manager     Sheri Campos
# ...

# %%
employees[(employees['Current Employee Rating'] > 3) & (employees['PayZone'] == 'Zone C')]
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 18     3445      Reid        Park  16-Jan-21        NaN
# 26     3453   Bridger      Carter  13-Oct-22        NaN
# 27     3454      Leon       Beard  11-Sep-22        NaN
# 28     3455   Charity     Miranda  29-Jun-21  05-Jul-22
# ...     ...       ...         ...        ...        ...
# 2945   3372     Kylie       Roman  14-Jan-23  14-Mar-23
# 2952   3379   Marquis      Joseph  09-Apr-23  14-Jun-23
# 2955   3382     Romeo      Gordon  10-Nov-18        NaN
# 2979   3406  Serenity  Montgomery  25-Mar-20  26-Apr-23
# 2980   3407    Kamila     Sanders  15-Apr-21  11-May-23
#
#                          Title         Supervisor  \
# 0      Production Technician I       Peter Oneill
# 18          Area Sales Manager  Michelle Mitchell
# 26          Area Sales Manager   Elizabeth Taylor
# 27          Area Sales Manager       Brian Dunlap
# ...
