# %%
import pandas as pd
from sqlalchemy import create_engine
# connection string
engine = create_engine(
    "postgresql+psycopg2://udemy:udemy123@localhost:5434/udemy_master_of_pandas"
)

# read table
employees = pd.read_sql("SELECT * FROM master.employees;", engine)

# %%
df1=pd.DataFrame(
    {
        'Name':['Yash','Rafid','John'],
        'Age':[25,30,35],
    },index=[101,102,103]
)

# %%
df2=pd.DataFrame(
    {
        'Salary':[55000,70000,9000],
    },index=[101,102,103]
)

# %%
df1
# Out:
#       Name  Age
# 101   Yash   25
# 102  Rafid   30
# 103   John   35

# %%
df2
# Out:
#      Salary
# 101   55000
# 102   70000
# 103    9000

# %%
df1.index
# Out:
# Index([101, 102, 103], dtype='int64')

# %%
df2.index
# Out:
# Index([101, 102, 103], dtype='int64')

# %%
df1.join(df2)
# Out:
#       Name  Age  Salary
# 101   Yash   25   55000
# 102  Rafid   30   70000
# 103   John   35    9000

# %%
df1
# Out:
#       Name  Age
# 101   Yash   25
# 102  Rafid   30
# 103   John   35

# %%
df1.join(df2, how='inner')
# Out:
#       Name  Age  Salary
# 101   Yash   25   55000
# 102  Rafid   30   70000
# 103   John   35    9000

# %%
df1
# Out:
#       Name  Age
# 101   Yash   25
# 102  Rafid   30
# 103   John   35

# %%
df2=pd.DataFrame(
    {
        'Salary':[55000,70000,9000],
    },index=[102,103,104]
)

# %%
df1
# Out:
#       Name  Age
# 101   Yash   25
# 102  Rafid   30
# 103   John   35

# %%
df2
# Out:
#      Salary
# 102   55000
# 103   70000
# 104    9000

# %%
df1.join(df2)
# Out:
#       Name  Age   Salary
# 101   Yash   25      NaN
# 102  Rafid   30  55000.0
# 103   John   35  70000.0

# %%
df1.join(df2,how='inner')
# Out:
#       Name  Age  Salary
# 102  Rafid   30   55000
# 103   John   35   70000

# %%
df1.join(df2,how='outer')
# Out:
#       Name   Age   Salary
# 101   Yash  25.0      NaN
# 102  Rafid  30.0  55000.0
# 103   John  35.0  70000.0
# 104    NaN   NaN   9000.0

# %%
df1.join(df2,how='left')
# Out:
#       Name  Age   Salary
# 101   Yash   25      NaN
# 102  Rafid   30  55000.0
# 103   John   35  70000.0

# %%
df1.join(df2,how='right')
# Out:
#       Name   Age  Salary
# 102  Rafid  30.0   55000
# 103   John  35.0   70000
# 104    NaN   NaN    9000

# %%
df1=pd.DataFrame(
    {
        'ID':[101,102,103],
        'Name':['Yash','Rafid','John'],
        'Age':[25,30,35],
    }
)
df2=pd.DataFrame(
    {
        'ID':[102,103,104],
        'Salary':[55000,70000,90000],
    }
)

# %% [markdown]
# df1

# %%
df1
# Out:
#     ID   Name  Age
# 0  101   Yash   25
# 1  102  Rafid   30
# 2  103   John   35

# %%
df2
# Out:
#     ID  Salary
# 0  101   55000
# 1  102   70000
# 2  103   90000

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.set_index('ID').join(df2.set_index('ID'))
# Out:
#       Name  Age   Salary
# ID
# 101   Yash   25      NaN
# 102  Rafid   30  55000.0
# 103   John   35  70000.0

# %%
df1.set_index('ID').join(df2.set_index('ID'),how='inner')
# Out:
#       Name  Age  Salary
# ID
# 102  Rafid   30   55000
# 103   John   35   70000

# %%
df1.set_index('ID').join(df2.set_index('ID'),how='right')
# Out:
#       Name   Age  Salary
# ID
# 102  Rafid  30.0   55000
# 103   John  35.0   70000
# 104    NaN   NaN   90000

# %%
df1.set_index('ID').join(df2.set_index('ID'),how='left')
# Out:
#       Name  Age   Salary
# ID
# 101   Yash   25      NaN
# 102  Rafid   30  55000.0
# 103   John   35  70000.0

# %%
df1.set_index('ID').join(df2.set_index('ID'),how='outer')
# Out:
#       Name   Age   Salary
# ID
# 101   Yash  25.0      NaN
# 102  Rafid  30.0  55000.0
# 103   John  35.0  70000.0
# 104    NaN   NaN  90000.0

# %%
df1.merge(df2,how='inner')
# Out:
#     ID   Name  Age  Salary
# 0  102  Rafid   30   55000
# 1  103   John   35   70000

# %%
df1
# Out:
#     ID   Name  Age
# 0  101   Yash   25
# 1  102  Rafid   30
# 2  103   John   35

# %%
df1.merge(df2,how='outer')
# Out:
#     ID   Name   Age   Salary
# 0  101   Yash  25.0      NaN
# 1  102  Rafid  30.0  55000.0
# 2  103   John  35.0  70000.0
# 3  104    NaN   NaN  90000.0

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...
