# %%
import pandas as pd

# %%
df1=pd.DataFrame({
    'A':[12,19,23],
    'B':[12,21,32],
})
df2=pd.DataFrame({
    'A':[111,None,232],
    'B':[None,212,None],
})

# %%
df1
# Out:
#     A   B
# 0  12  12
# 1  19  21
# 2  23  32

# %%
df2
# Out:
#        A      B
# 0  111.0    NaN
# 1    NaN  212.0
# 2  232.0    NaN

# %%
df1.update(df2)

# %%
df1
# Out:
#      A    B
# 0  111   12
# 1   19  212
# 2  232   32

# %%
df1=pd.DataFrame({
    'A':[12,19,23],
    'B':[12,21,32],
})
df2=pd.DataFrame({
    'A':[111,None,232],
    'B':[None,212,None],
})

# %%
df1.update(df2,filter_func=lambda x:x > 15)

# %%
df1=pd.DataFrame({
    'A':[11,19,23],
    'B':[12,21,32],
})
df2=pd.DataFrame({
    'A':[111,None,232],
    'B':[None,212,None],
})

# %%
 def update_on_condition(x): 
     return x > 21

# %%
df1.update(df2,filter_func=update_on_condition)

# %%
df1
# Out:
#      A   B
# 0   11  12
# 1   19  21
# 2  232  32

# %%
df1=pd.DataFrame({
    'A':[11,19,23],
    'B':[12,21,32]
},index=['a','b','c'])
df2=pd.DataFrame({
    'A':[111,232],
    'B':[212,222]
}, index=['b','c'])

# %%
df1
# Out:
#     A   B
# a  11  12
# b  19  21
# c  23  32

# %%
df2
# Out:
#      A    B
# b  111  212
# c  232  222

# %%
df1.update(df2)

# %%
df1
# Out:
#      A    B
# a   11   12
# b  111  212
# c  232  222

# %%
df2
# Out:
#      A    B
# b  111  212
# c  232  222

# %%
pd.concat([df1,df2])
# Out:
#      A    B
# a   11   12
# b  111  212
# c  232  222
# b  111  212
# c  232  222

# %%
pd.concat([df1,df2], ignore_index= True)
# Out:
#      A    B
# 0   11   12
# 1  111  212
# 2  232  222
# 3  111  212
# 4  232  222

# %%
pd.concat([df1,df2], ignore_index= True ,axis=0)
# Out:
#      A    B
# 0   11   12
# 1  111  212
# 2  232  222
# 3  111  212
# 4  232  222

# %%
pd.concat([df1,df2], ignore_index= True ,axis=1)
# Out:
#      0    1      2      3
# a   11   12    NaN    NaN
# b  111  212  111.0  212.0
# c  232  222  232.0  222.0

# %%
pd.concat([df1,df2], join='inner')
# Out:
#      A    B
# a   11   12
# b  111  212
# c  232  222
# b  111  212
# c  232  222

# %%
df1=pd.DataFrame({
    'A':[11,19,23],
    'B':[12,21,32]
},index=['101','102','103'])
df2=pd.DataFrame({
    'A':[111,232],
    'B':[212,222]
}, index=['102','104'])

# %%
pd.concat([df1,df2], join='inner')
# Out:
#        A    B
# 101   11   12
# 102   19   21
# 103   23   32
# 102  111  212
# 104  232  222

# %%
pd.concat([df1,df2], join='inner' , axis=1)
# Out:
#       A   B    A    B
# 102  19  21  111  212

# %%
pd.concat([df1,df2], join='outer' )
# Out:
#        A    B
# 101   11   12
# 102   19   21
# 103   23   32
# 102  111  212
# 104  232  222

# %%
pd.concat([df1,df2], keys=['df1','df2'])
# Out:
#            A    B
# df1 101   11   12
#     102   19   21
#     103   23   32
# df2 102  111  212
#     104  232  222

# %%
df1
# Out:
#       A   B
# 101  11  12
# 102  19  21
# 103  23  32

# %%
df2
# Out:
#        A    B
# 102  111  212
# 104  232  222

# %%
df1.combine(df2 , func = lambda x,y : x+y)
# Out:
#          A      B
# 101    NaN    NaN
# 102  130.0  233.0
# 103    NaN    NaN
# 104    NaN    NaN

# %%
df1.reset_index(drop=True , inplace=True)

# %%
df1
# Out:
#     A   B
# 0  11  12
# 1  19  21
# 2  23  32

# %%
df2
# Out:
#        A    B
# 102  111  212
# 104  232  222

# %%
df1.combine(df2 , func = lambda x,y : x+y)
# Out:
#       A   B
# 0   NaN NaN
# 1   NaN NaN
# 2   NaN NaN
# 102 NaN NaN
# 104 NaN NaN

# %%
df1.combine(df2 , func = lambda x,y : x+y , fill_value=0)
# Out:
#          A      B
# 0     11.0   12.0
# 1     19.0   21.0
# 2     23.0   32.0
# 102  111.0  212.0
# 104  232.0  222.0
