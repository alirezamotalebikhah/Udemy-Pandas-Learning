# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(3,3) , columns=['A','B','C'])
df
# Out:
#           A         B         C
# 0  0.924563  0.557934  0.451749
# 1  0.278303  0.266726  0.108606
# 2  0.936847  0.430101  0.079224

# %%
df.min()
# Out:
# A    0.278303
# B    0.266726
# C    0.079224
# dtype: float64

# %%
min(df.min())
# Out:
# 0.07922431601488655

# %%
_mindf = df.min()

# %%
_mindf.min()
# Out:
# np.float64(0.07922431601488655)

# %%
df.max()
# Out:
# A    0.936847
# B    0.557934
# C    0.451749
# dtype: float64

# %%
max(df.max())
# Out:
# 0.9368474229477589

# %%
_maxdf = df.max()

# %%
_maxdf.max()
# Out:
# np.float64(0.9368474229477589)

# %%
df.sum()
# Out:
# A    2.139714
# B    1.254761
# C    0.639579
# dtype: float64

# %%
sum(df.sum())
# Out:
# 4.034054761273164

# %%
df.mean()
# Out:
# A    0.713238
# B    0.418254
# C    0.213193
# dtype: float64

# %%
meandf= df.mean()

# %%
meandf.mean()
# Out:
# np.float64(0.44822830680812925)

# %%
meandf.apply(np.mean)
# Out:
# A    0.713238
# B    0.418254
# C    0.213193
# dtype: float64

# %%
meandf
# Out:
# A    0.713238
# B    0.418254
# C    0.213193
# dtype: float64

# %%
meandf.apply(np.median)
# Out:
# A    0.713238
# B    0.418254
# C    0.213193
# dtype: float64

# %%
df.std()
# Out:
# A    0.376715
# B    0.145965
# C    0.207117
# dtype: float64

# %%
stddf=df.std()

# %%
stddf.std()
# Out:
# np.float64(0.11954655894408425)

# %%
vardf = df.var()

# %%
vardf.std()
# Out:
# np.float64(0.06431273107005693)

# %%
vardf.var()
# Out:
# np.float64(0.0041361273776894655)
